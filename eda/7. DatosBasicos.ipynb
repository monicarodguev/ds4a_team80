# %% [markdown]
# # 7. Datos Basicos
# ## 0. Previos
#
# Se cargan las bases y las librerías a utilizar.

# %%
# Librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Base de interés
DatosBasicos = pd.read_excel('C:/Users/Usuario/Documents/Eda_Adherencia/Datosbasicos.xlsx')
DatosBasicos.head()
# Out:
#        ID  edad genero      escolaridad  EstadoCivil   Preferencia  \
# 0  500547  58.0      M       SECUNDARIA   CASADO (A)  HETEROSEXUAL
# 1  500588  15.0      M         PRIMARIA  SOLTERO (A)           NaN
# 2  502989  29.0      M    UNIVERSITARIO  SOLTERO (A)  HETEROSEXUAL
# 3  506808  11.0      M  EDAD PREESCOLAR  SOLTERO (A)  HETEROSEXUAL
# 4  512938  22.0      F       SECUNDARIA  SOLTERO (A)  HETEROSEXUAL
#
#    Departamento    Ciudad  Estrato    Zona AcompaÃ±ante NivelSocioEconomico  \
# 0     ANTIOQUIA  MEDELLIN      3.0  URBANA     PACIENTE                   A
# 1  CUNDINAMARCA    BOGOTA      2.0  URBANA        MADRE                   B
# 2     ANTIOQUIA  MEDELLIN      3.0  URBANA        MADRE                   A
# 3     ANTIOQUIA     BELLO      1.0  URBANA        MADRE                   A
# 4     ANTIOQUIA  MEDELLIN      3.0  URBANA     PACIENTE                   A
#
#      Ocupacion       Regimen TipoAfiliacion  RelacionLaboral  \
# ...

# %%
# Base de datos de adherencia
adherencia = pd.read_excel('C:/Users/Usuario/Documents/Eda_Adherencia/Adherencia.xlsx')
adherencia.head()
# Out:
#    ds_identificacion FE_ENTREVISTA Morisky_Green      Smaq1    Smaq2  \
# 0            1101180    2012-04-24  NO ADHERENTE  ADHERENTE  95-100%
# 1            1101180    2012-11-26     ADHERENTE  ADHERENTE  95-100%
# 2             529410    2012-04-19  NO ADHERENTE  ADHERENTE  95-100%
# 3             979605    2013-03-04  NO ADHERENTE  ADHERENTE  95-100%
# 4            1198956    2012-05-16  NO ADHERENTE  ADHERENTE  95-100%
#
#            Espa  nm_espa Cualitativo_ponderado Cuantitativo_ponderado
# 0  NO ADHERENTE      4.0          NO ADHERENTE                95-100%
# 1     ADHERENTE      6.0             ADHERENTE                95-100%
# 2  NO ADHERENTE      6.0          NO ADHERENTE                95-100%
# 3  NO ADHERENTE      6.0          NO ADHERENTE                95-100%
# 4  NO ADHERENTE      6.0          NO ADHERENTE                95-100%

# %%
adherencia = adherencia.rename(columns={'ds_identificacion': 'ID'})
print(adherencia.columns)
print(DatosBasicos.columns)
# Out:
# Index(['ID', 'FE_ENTREVISTA', 'Morisky_Green', 'Smaq1', 'Smaq2', 'Espa',
#        'nm_espa', 'Cualitativo_ponderado', 'Cuantitativo_ponderado'],
#       dtype='object')
# Index(['ID', 'edad', 'genero', 'escolaridad', 'EstadoCivil', 'Preferencia',
#        'Departamento', 'Ciudad', 'Estrato', 'Zona', 'AcompaÃ±ante',
#        'NivelSocioEconomico', 'Ocupacion', 'Regimen', 'TipoAfiliacion',
#        'RelacionLaboral', 'FE_NACIMIENTO'],
#       dtype='object')

# %%
# Merge Datos basico a adherencia 
Agregada = adherencia.merge(DatosBasicos, on="ID",how ='left')
Agregada.head()
# Out:
#         ID FE_ENTREVISTA Morisky_Green      Smaq1    Smaq2          Espa  \
# 0  1101180    2012-04-24  NO ADHERENTE  ADHERENTE  95-100%  NO ADHERENTE
# 1  1101180    2012-11-26     ADHERENTE  ADHERENTE  95-100%     ADHERENTE
# 2   529410    2012-04-19  NO ADHERENTE  ADHERENTE  95-100%  NO ADHERENTE
# 3   979605    2013-03-04  NO ADHERENTE  ADHERENTE  95-100%  NO ADHERENTE
# 4  1198956    2012-05-16  NO ADHERENTE  ADHERENTE  95-100%  NO ADHERENTE
#
#    nm_espa Cualitativo_ponderado Cuantitativo_ponderado  edad  ...    Ciudad  \
# 0      4.0          NO ADHERENTE                95-100%  59.0  ...      CALI
# 1      6.0             ADHERENTE                95-100%  59.0  ...      CALI
# 2      6.0          NO ADHERENTE                95-100%  22.0  ...    BOGOTA
# 3      6.0          NO ADHERENTE                95-100%  85.0  ...  MEDELLIN
# 4      6.0          NO ADHERENTE                95-100%  13.0  ...      CALI
#
# ...

# %% [markdown]
# ## 1. Tipos

# %%
Agregada.describe()
# Out:
#                  ID     nm_espa         edad      Estrato
# count  5.348000e+03  5339.00000  5346.000000  5345.000000
# mean   1.238999e+06     5.11725    42.678451     2.921983
# std    4.284595e+05     1.80465    18.483306     0.900606
# min    5.005470e+05     0.00000     5.000000     1.000000
# 25%    8.743420e+05     5.00000    29.000000     3.000000
# 50%    1.226479e+06     6.00000    43.000000     3.000000
# 75%    1.617372e+06     6.00000    58.000000     3.000000
# max    1.999629e+06     6.00000    88.000000     6.000000

# %%
Agregada.dtypes
# Out:
# ID                                 int64
# FE_ENTREVISTA             datetime64[ns]
# Morisky_Green                     object
# Smaq1                             object
# Smaq2                             object
# Espa                              object
# nm_espa                          float64
# Cualitativo_ponderado             object
# Cuantitativo_ponderado            object
# edad                             float64
# genero                            object
# escolaridad                       object
# EstadoCivil                       object
# Preferencia                       object
# Departamento                      object
# Ciudad                            object
# Estrato                          float64
# Zona                              object
# AcompaÃ±ante                      object
# NivelSocioEconomico               object
# Ocupacion                         object
# Regimen                           object
# TipoAfiliacion                    object
# ...

# %% [markdown]
# ## 2. Aporte Conceptual

# %% [markdown]
# ## 3. Calidad

# %%
Agregada.columns
# Out:
# Index(['ID', 'FE_ENTREVISTA', 'Morisky_Green', 'Smaq1', 'Smaq2', 'Espa',
#        'nm_espa', 'Cualitativo_ponderado', 'Cuantitativo_ponderado', 'edad',
#        'genero', 'escolaridad', 'EstadoCivil', 'Preferencia', 'Departamento',
#        'Ciudad', 'Estrato', 'Zona', 'AcompaÃ±ante', 'NivelSocioEconomico',
#        'Ocupacion', 'Regimen', 'TipoAfiliacion', 'RelacionLaboral',
#        'FE_NACIMIENTO'],
#       dtype='object')

# %% [markdown]
# ## 4. Exploración
# ### 4.1 Distribuciones
# ### (a) Edad

# %%
# plot
base_gf = Agregada.groupby('edad').count().reset_index()

fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['edad'], base_gf['ID'] )

# %%
# Relación adherencia con la edad
Agregada.columns
# Out:
# Index(['ID', 'FE_ENTREVISTA', 'Morisky_Green', 'Smaq1', 'Smaq2', 'Espa',
#        'nm_espa', 'Cualitativo_ponderado', 'Cuantitativo_ponderado', 'edad',
#        'genero', 'escolaridad', 'EstadoCivil', 'Preferencia', 'Departamento',
#        'Ciudad', 'Estrato', 'Zona', 'AcompaÃ±ante', 'NivelSocioEconomico',
#        'Ocupacion', 'Regimen', 'TipoAfiliacion', 'RelacionLaboral',
#        'FE_NACIMIENTO'],
#       dtype='object')

# %%
plt.figure()
Agregada.groupby(["edad","Cualitativo_ponderado"]).agg({'ID': ['count']}).unstack().plot()

# %% [markdown]
# ### (b) Estrato

# %%
# plot
base_gf = Agregada.groupby('Estrato').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Estrato'], base_gf['ID'] )

# %%
# Relación de la adherencia con el estrato

# %%
Agregada.groupby(["Estrato","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                  ID
#                               count
# Estrato Cualitativo_ponderado
# 1.0     ADHERENTE               224
#         NO ADHERENTE             61
#         NO APLICA                36
# 2.0     ADHERENTE               712
#         NO ADHERENTE            181
#         NO APLICA                83
# 3.0     ADHERENTE              2348
#         NO ADHERENTE            579
#         NO APLICA               287
# 4.0     ADHERENTE               365
#         NO ADHERENTE             94
#         NO APLICA                39
# 5.0     ADHERENTE               186
#         NO ADHERENTE             65
#         NO APLICA                11
# 6.0     ADHERENTE                39
#         NO ADHERENTE             15
#         NO APLICA                 7

# %% [markdown]
# ### (c) Genero

# %%
Agregada.columns
# Out:
# Index(['ID', 'FE_ENTREVISTA', 'Morisky_Green', 'Smaq1', 'Smaq2', 'Espa',
#        'nm_espa', 'Cualitativo_ponderado', 'Cuantitativo_ponderado', 'edad',
#        'genero', 'escolaridad', 'EstadoCivil', 'Preferencia', 'Departamento',
#        'Ciudad', 'Estrato', 'Zona', 'AcompaÃ±ante', 'NivelSocioEconomico',
#        'Ocupacion', 'Regimen', 'TipoAfiliacion', 'RelacionLaboral',
#        'FE_NACIMIENTO'],
#       dtype='object')

# %%
# Relación de la adherencia con el genero
# plot
base_gf = Agregada.groupby('genero').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['genero'], base_gf['ID'] )

# %%
Agregada.groupby(["genero","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                 ID
#                              count
# genero Cualitativo_ponderado
# F      ADHERENTE              2715
#        NO ADHERENTE            705
#        NO APLICA               318
# M      ADHERENTE              1162
#        NO ADHERENTE            290
#        NO APLICA               145

# %% [markdown]
# ### (d) Escolaridad

# %%
# Relación de la adherencia con el genero
escolaridad

# %%
# plot
base_gf = Agregada.groupby('escolaridad').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['escolaridad'], base_gf['ID'] )

# %%
Agregada.groupby(["escolaridad","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                          ID
#                                       count
# escolaridad     Cualitativo_ponderado
# ANALFABETA      ADHERENTE                29
#                 NO ADHERENTE              1
#                 NO APLICA                 2
# EDAD PREESCOLAR ADHERENTE                96
#                 NO ADHERENTE             19
#                 NO APLICA                13
# POSGRADO        ADHERENTE                25
#                 NO ADHERENTE             17
#                 NO APLICA                 1
# PRIMARIA        ADHERENTE               874
#                 NO ADHERENTE            213
#                 NO APLICA               133
# SECUNDARIA      ADHERENTE              1861
#                 NO ADHERENTE            472
#                 NO APLICA               215
# TECNICO         ADHERENTE               286
#                 NO ADHERENTE             89
#                 NO APLICA                37
# ...

# %% [markdown]
# ### (e) Estado civil

# %%
# Relación de la adherencia con el estado civil
EstadoCivil

# %%
# plot
base_gf = Agregada.groupby('EstadoCivil').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['EstadoCivil'], base_gf['ID'] )

# %%
Agregada.groupby(["EstadoCivil","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                       ID
#                                    count
# EstadoCivil  Cualitativo_ponderado
# CASADO (A)   ADHERENTE              1572
#              NO ADHERENTE            401
#              NO APLICA               183
# SEPARADO (A) ADHERENTE               137
#              NO ADHERENTE             34
#              NO APLICA                20
# SIN DEFINIR  ADHERENTE                 1
#              NO APLICA                 1
# SOLTERO (A)  ADHERENTE              1750
#              NO ADHERENTE            466
#              NO APLICA               207
# UNIÓN LIBRE  ADHERENTE               328
#              NO ADHERENTE             87
#              NO APLICA                41
# VIUDO (A)    ADHERENTE                89
#              NO ADHERENTE              7
#              NO APLICA                11

# %% [markdown]
# ### (f) Preferencia sexual

# %%
# Relación de la adherencia con la preferencia sexual
Preferencia

# %%
# plot
base_gf = Agregada.groupby('Preferencia').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Preferencia'], base_gf['ID'] )

# %%
Agregada.groupby(["Preferencia","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                       ID
#                                    count
# Preferencia  Cualitativo_ponderado
# BISEXUAL     ADHERENTE                 2
# HETEROSEXUAL ADHERENTE              1107
#              NO ADHERENTE            320
#              NO APLICA               113
# SIN DEFINIR  ADHERENTE                47
#              NO ADHERENTE             14
#              NO APLICA                 5

# %% [markdown]
# ### (g) Departamento

# %%
Departamento

# %%
# plot
base_gf = Agregada.groupby('Departamento').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Departamento'], base_gf['ID'] )

# %%
Agregada.groupby(["Departamento","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                       ID
#                                    count
# Departamento Cualitativo_ponderado
# ANTIOQUIA    ADHERENTE              3455
#              NO ADHERENTE            911
#              NO APLICA               384
# ATLANTICO    ADHERENTE               146
#              NO ADHERENTE             25
#              NO APLICA                36
# BOLIVAR      ADHERENTE                 2
#              NO APLICA                 2
# CALDAS       ADHERENTE                76
#              NO ADHERENTE             14
#              NO APLICA                 7
# CUNDINAMARCA ADHERENTE                86
#              NO ADHERENTE             21
#              NO APLICA                14
# MAGDALENA    ADHERENTE                 2
# QUINDIO      ADHERENTE                 4
#              NO APLICA                 3
# RISARALDA    ADHERENTE                10
#              NO ADHERENTE              1
#              NO APLICA                 1
# ...

# %% [markdown]
# ### (h) Ciudad

# %%
Ciudad

# %%
Agregada.groupby(["Ciudad","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                             ID
#                                          count
# Ciudad             Cualitativo_ponderado
# ANDES              ADHERENTE                 8
#                    NO ADHERENTE              2
#                    NO APLICA                 1
# ARMENIA            ADHERENTE                 4
#                    NO APLICA                 3
# BARBOSA            ADHERENTE                13
#                    NO ADHERENTE              7
#                    NO APLICA                 2
# BARRANQUILLA       ADHERENTE               134
#                    NO ADHERENTE             24
#                    NO APLICA                35
# BELLO              ADHERENTE               249
#                    NO ADHERENTE             84
#                    NO APLICA                45
# BOGOTA             ADHERENTE                74
#                    NO ADHERENTE             15
#                    NO APLICA                 9
# ...

# %% [markdown]
# ### (j) Zona

# %%
Zona

# %%
# plot
base_gf = Agregada.groupby('Zona').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Zona'], base_gf['ID'] )

# %%
Agregada.groupby(["Zona","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                 ID
#                              count
# Zona   Cualitativo_ponderado
# RURAL  ADHERENTE               171
#        NO ADHERENTE             49
#        NO APLICA                20
# URBANA ADHERENTE              3703
#        NO ADHERENTE            946
#        NO APLICA               443

# %% [markdown]
# ### (k) Acompañante

# %%
AcompaÃ±ante

# %%
# plot
base_gf = Agregada.groupby('AcompaÃ±ante').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['AcompaÃ±ante'], base_gf['ID'] )

# %%
Agregada.groupby(["AcompaÃ±ante","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                           ID
#                                        count
# AcompaÃ±ante     Cualitativo_ponderado
# AMIGO            ADHERENTE                32
#                  NO ADHERENTE              7
#                  NO APLICA                 8
# FAMILIAR CERCANO ADHERENTE               165
#                  NO ADHERENTE             46
#                  NO APLICA                19
# HERMANO(A)       ADHERENTE               107
#                  NO ADHERENTE             34
#                  NO APLICA                 9
# HIJO(A)          ADHERENTE               183
#                  NO ADHERENTE             34
#                  NO APLICA                21
# MADRE            ADHERENTE               708
#                  NO ADHERENTE            224
#                  NO APLICA                86
# OTRO, CUAL?      ADHERENTE                14
#                  NO ADHERENTE              6
#                  NO APLICA                 2
# ...

# %% [markdown]
# ### (l) NivelSocioEconomico

# %%
NivelSocioEconomico

# %%
# plot
base_gf = Agregada.groupby('NivelSocioEconomico').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['NivelSocioEconomico'], base_gf['ID'] )

# %%
Agregada.groupby(["NivelSocioEconomico","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                              ID
#                                           count
# NivelSocioEconomico Cualitativo_ponderado
# A                   ADHERENTE              2866
#                     NO ADHERENTE            735
#                     NO APLICA               368
# B                   ADHERENTE               763
#                     NO ADHERENTE            213
#                     NO APLICA                71
# C                   ADHERENTE               175
#                     NO ADHERENTE             36
#                     NO APLICA                16
# NIVEL 0 DEL SISBEN  ADHERENTE                21
#                     NO ADHERENTE              4
#                     NO APLICA                 1
# NIVEL 1 DEL SISBEN  ADHERENTE                32
#                     NO ADHERENTE              5
#                     NO APLICA                 3
# NIVEL 2 DEL SISBEN  ADHERENTE                 2
#                     NO ADHERENTE              2
# ...

# %% [markdown]
# ### (m) Ocupacion

# %%
Ocupacion

# %%
# plot
base_gf = Agregada.groupby('Ocupacion').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Ocupacion'], base_gf['ID'] )

# %%
Agregada.groupby(["Ocupacion","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                        ID
#                                     count
# Ocupacion     Cualitativo_ponderado
# AMA DE CASA   ADHERENTE               538
#               NO ADHERENTE            132
#               NO APLICA                67
# DESEMPLEADO   ADHERENTE                29
#               NO ADHERENTE              4
#               NO APLICA                 5
# EMPLEADO      ADHERENTE              1943
#               NO ADHERENTE            515
#               NO APLICA               234
# ESTUDIANTE    ADHERENTE               651
#               NO ADHERENTE            188
#               NO APLICA                72
# INDEPENDIENTE ADHERENTE               171
#               NO ADHERENTE             51
#               NO APLICA                20
# JUBILADO      ADHERENTE                74
#               NO ADHERENTE             24
#               NO APLICA                16
# PENSIONADO    ADHERENTE               224
# ...

# %% [markdown]
# ### (n) Regimen

# %%
Regimen

# %%
# plot
base_gf = Agregada.groupby('Regimen').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['Regimen'], base_gf['ID'] )

# %%
Agregada.groupby(["Regimen","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                       ID
#                                    count
# Regimen      Cualitativo_ponderado
# CONTRIBUTIVO ADHERENTE              3793
#              NO ADHERENTE            982
#              NO APLICA               454
# OTRO         ADHERENTE                 3
#              NO ADHERENTE              2
# PARTICULAR   ADHERENTE                 7
#              NO APLICA                 2
# SUBSIDIADO   ADHERENTE                56
#              NO ADHERENTE             11
#              NO APLICA                 5

# %% [markdown]
# ### (o) TipoAfiliacion

# %%
TipoAfiliacion

# %%
# plot
base_gf = Agregada.groupby('TipoAfiliacion').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['TipoAfiliacion'], base_gf['ID'] )

# %%
Agregada.groupby(["TipoAfiliacion","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                         ID
#                                      count
# TipoAfiliacion Cualitativo_ponderado
# BENEFICIARIO   ADHERENTE              1475
#                NO ADHERENTE            395
#                NO APLICA               168
# COTIZANTE      ADHERENTE              2341
#                NO ADHERENTE            592
#                NO APLICA               290
# SUBSIDIADO     ADHERENTE                43
#                NO ADHERENTE              8
#                NO APLICA                 3

# %% [markdown]
# ### (p) RelacionLaboral

# %%
RelacionLaboral

# %%
# plot
base_gf = Agregada.groupby('RelacionLaboral').count().reset_index()
fig, ax = plt.subplots(figsize=(15, 5))
rects1 = ax.bar(base_gf['RelacionLaboral'], base_gf['ID'] )

# %%
Agregada.groupby(["RelacionLaboral","Cualitativo_ponderado"]).agg({'ID': ['count']})
# Out:
#                                          ID
#                                       count
# RelacionLaboral Cualitativo_ponderado
# EMPLEADO        ADHERENTE              1973
#                 NO ADHERENTE            519
#                 NO APLICA               235
# INDEPENDIENTE   ADHERENTE               211
#                 NO ADHERENTE             62
#                 NO APLICA                26
# MENOR NO LABORA ADHERENTE               563
#                 NO ADHERENTE            158
#                 NO APLICA                69
# PENSIONADO      ADHERENTE               294
#                 NO ADHERENTE             49
#                 NO APLICA                30
# SIN EMPLEO      ADHERENTE               818
#                 NO ADHERENTE            207
#                 NO APLICA               101

# %% [markdown]
# ## 5. Definiciones Modelo de Datos
# ### 5.1 Transformación y Limpieza

# %% [markdown]
# * Separar la variable de Fecha de nacimiento en Año, Mes y Día

# %% [markdown]
# ### 5.2 Modelo de Datos

# %% [markdown]
# El cruce debe hacerce por ds_identificacion

# %% [markdown]
# ### 5.3 Definición de Variables
